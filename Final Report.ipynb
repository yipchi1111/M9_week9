# %% [markdown]
# # Coursera Capstone

# %% [markdown]
# #### IBM Applied Data Science Capstone (Module 9)

# %% [markdown]
# # Final Report

# %% [markdown]
# ## 1. Introduction
# Among the world, Canada is one of the renowned places that allow people to relax. You may find some unique and wonderful place to destress in Canada. Stanley Park and mountains are fantastic in Canada, for instance. When it comes to enjoying our life, the first thing recurring to our mind is food.
#
# Canada is a diversified country with various types of cuisine. When it comes to categorizing these dishes into Canadian food, it might be a challenging task since Canadian cuisine varies significantly depending on the regions of the nation in Canada. As a matter of fact, most of the people living in Canada enjoy eating western cuisine which are having similar characteristics with the cuisine in Europe and American regions. These cuisines are mainly of a strong emphasis on the ingredient of food such as the composition of fresh fruits and vegetable and questionable amounts of salt and sugar.
#
# ## 2. Business Problem
# In my project, I will attempt to demonstrate the fact that Toronto has a wide variety of restaurants. The major purpose of this project is to facilitate the opening of new food shops in Toronto with considering the demographics, characteristics and income distribution. More importantly, choosing a suitable and favourable location or site facilitates making a better decision in business operation, determining the future and prospect of a business.

# %% [markdown]
# ## 3. Interest
# Undoubtedly, businessmen in Canada would be very interested in accurate prediction and location to operate their catering businesses in a successful way by having competitive advantage and deploying unique business values. Others especially the lcoal Canadians who are interested in Canadian cuisine and fans and fantasy people around the world may also be interested.

# %% [markdown]
# ## 4. Data Acquisition
# For the sources of data used in the analysis, it includes a website: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M. This website demonstrates some information related to "Toronto City data that contains list Boroughs, Neighborhoods". Moreover, the analysis would use the data from another website: http://cocl.us/Geospatial_data. This website includes the latitudes and longitudes of each neighbourhood.

# %% [markdown]
# ## 5. Data Cleaning
# Data downloaded or acquired from multiple sources were not limited to the above mentioned sources and they were all combined into one table. Thus, it is possible to have problem in handling the data for analysis and prediction. Data Cleaning is needed and necessary to deal with this data problem. I would divide the data into different columns such as 'Postcode', 'Borough' and 'Neighbourhood'to categorize and demonstrate the required information.
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
#
# ### After categorization and expressing the data in table format, I would combine the latitudes and longitudes data into the above table for futher analysis.
# ![image.png](attachment:image.png)
# For instance, from the above table, we can see that the data are expressed in table form by using 'Borough', 'Neighbourhood', 'Postcode', 'Latitude', and 'Longitude' in order to facilitate the identification of respective location.

# %% [markdown]
# ## 6. Methodology
# For the methodology, first, it is required to obtain the information related to the neighbourhoods in Canada. The information can be obtained from https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M which includes Toronto City data that contains list Boroughs, Neighborhoods. Then, it is necessary to do use Python requests and beautifulsoup packages in order to extract and obtain the information related to neighborhoods data. As this can only allow us to get the names of neighborhoods, it is necessary for us to identify the latitudes and longitudes of each neighborhood so as to facilitate the application of Foursquare API. After combining the data, it is possible for us to type the code to genereate a map showing the location and cluster by using the Folium package.

# %% [markdown]
# ## 7. Results
# The results from the k-means clustering demonstrated that it is possible for us to identify the neighbourhoods into a cluster by using the above data such as latitudes, longtitudes and postcode.
#
# The results of the distribution of cluster are shown in the following map with dots in green color. They are mainly located near the shore in Canada.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 8. Limitations and Discussion
# In my project, there are some limitations due to limitation in the consideration of factor obtained from the data sources. Other qualitative data such as personal preference may also influence the decision making in choosing the location and site. On the other hand, my project used the Foursquare API with limitation in the use of API calls, affecting the final result and analysis of my project. In the future, it might be feasibe to access the paid accounts in order to deal with the mentioned limitation, facilitating the collection of more accurate results.

# %% [markdown]
# ## 9. Conclusion
# In my project, with intoduction of background information, it identifies the business problem. With the online sources of data, it is possible for us to extract the required data to identify the clusters and relationship of different data with the process of machine learning. After the analysis, there is an answer to the business problem, which is the neighnourhoold in cluster with green color dot should be the most prefered locations for businesses. These findings may facilitate the decision making process for respective businesses to capture the powerful opportunity in operating in highly potential sites.
